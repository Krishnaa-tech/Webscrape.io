# %% [markdown]
# > ## <center> TESTING MODEL

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import pickle
new_df = pd.read_csv('test_classified_articles_data.csv')

# %% [markdown]
# ### TESTING ON CUSTOM DATASET

# %%
import pickle
from sklearn.metrics import accuracy_score

# Assuming 'new_df' is your new dataset
# Load the pre-trained model
with open('trained_model.pkl', 'rb') as model_file:
    trained_model = pickle.load(model_file)

def apply_model_to_new_data(trained_model, new_data):
    # Load the pre-trained vectorizer and classifier
    vectorizer = trained_model['vectorizer']
    classifier = trained_model['classifier']

    # Transform the new text data using the pre-trained vectorizer
    X_new = vectorizer.transform(new_data['Article_Text'])

    # Predict the categories for the new dataset
    y_pred_new = classifier.predict(X_new)

    # Add the predicted categories to the new dataset
    new_data['Predicted_Category'] = y_pred_new

    return new_data

# Apply the pre-trained model to the new dataset
result_df = apply_model_to_new_data(trained_model, new_df)

# Calculate and display the test accuracy
y_true = result_df['Category']
y_pred = result_df['Predicted_Category']
accuracy = accuracy_score(y_true, y_pred)
print(f'Test Accuracy: {accuracy * 100:.2f}%')

# Display the result
result_df[['Article_Text', 'Category', 'Predicted_Category']]
# Out:
# Test Accuracy: 91.70%
#                                           Article_Text    Category  \
# 0    Vice President Jagdeep Dhankhar today stressed...  INDIA NEWS
# 1    The ministry of external affairs on Sunday den...  INDIA NEWS
# 2    Ahead of the Supreme Court (SC) verdict on Art...  INDIA NEWS
# 3    Chhattisgarh Chief Minister-designate Vishnu D...  INDIA NEWS
# 4    Union home minister Amit Shah on Sunday hit ou...  INDIA NEWS
# ..                                                 ...         ...
# 224  ISRO has lined up a series of exploration miss...     SCIENCE
# 225  Skygazers across the Americas turned their fac...     SCIENCE
# 226  ISRO will conduct three more test vehicle miss...     SCIENCE
# 227  A rare “ring of fire” eclipse of the sun cuts ...     SCIENCE
# 228  On the morning of October 9th, the National Bu...     SCIENCE
#
#     Predicted_Category
# 0           WORLD NEWS
# 1           INDIA NEWS
# 2            LIFESTYLE
# 3           INDIA NEWS
# ...
